# %%
e1 = int(input("introdcue e1:"))
e2 = int(input("introdcue e2:"))
e3 = int(input("introdcue e3:"))

numbers = [e1,e2,e3]
if all(0 <= num <= 9 for num in numbers):

    numbers.sort(reverse=False)
else : 
    print('introduce nuevamente el numero')
print(*numbers)
# Out:
# 1 3 6

# %% [markdown]
# ### Lista

# %%
numbers
# Out:
# [6, 4, 1]

# %% [markdown]
# ### Tupla

# %%
tupla = (1,2,3,4,5)
tupla
# Out:
# (1, 2, 3, 4, 5)

# %%
"A"+"B"+ "C"
# Out:
# 'ABC'
